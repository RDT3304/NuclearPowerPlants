# %%
#import main libraries to be used in the project
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import folium
import os

# %%
#import the dataset
df = pd.read_csv('Data/nuclear_power_plants.csv')
df.head()
# Out:
#    Id                  Name   Latitude  Longitude Country CountryCode  \
# 0   1                Ågesta  59.206000   18.08290  Sweden          SE
# 1   2  Akademik Lomonosov-1  69.709579  170.30625  Russia          RU
# 2   3  Akademik Lomonosov-2  69.709579  170.30625  Russia          RU
# 3   4              Akhvaz-1        NaN        NaN    Iran          IR
# 4   5              Akhvaz-2        NaN        NaN    Iran          IR
#
#         Status ReactorType        ReactorModel ConstructionStartAt  \
# 0     Shutdown        PHWR                 NaN          1957-12-01
# 1  Operational         PWR  KLT-40S 'Floating'          2007-04-15
# 2  Operational         PWR  KLT-40S 'Floating'          2007-04-15
# 3      Planned         NaN                 NaN                 NaN
# 4      Planned         NaN                 NaN                 NaN
#
#   OperationalFrom OperationalTo  Capacity              LastUpdatedAt  \
# 0      1964-05-01    1974-06-02       9.0  2015-05-24T04:51:37+03:00
# 1      2020-05-22           NaN      30.0                 2021-05-31
# 2      2020-05-22           NaN      30.0                 2021-05-31
# 3             NaN           NaN       NaN                        NaN
# 4             NaN           NaN       NaN                        NaN
#
#                  Source  IAEAId
# 0              WNA/IAEA   528.0
# 1  WNA/IAEA/Google Maps   895.0
# 2  WNA/IAEA/Google Maps   896.0
# 3                   WNA     NaN
# 4                   WNA     NaN

# %%
df.shape
# Out:
# (803, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 803 entries, 0 to 802
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   803 non-null    int64
#  1   Name                 803 non-null    object
#  2   Latitude             759 non-null    float64
#  3   Longitude            759 non-null    float64
#  4   Country              803 non-null    object
#  5   CountryCode          803 non-null    object
#  6   Status               803 non-null    object
#  7   ReactorType          794 non-null    object
#  8   ReactorModel         713 non-null    object
#  9   ConstructionStartAt  722 non-null    object
#  10  OperationalFrom      636 non-null    object
#  11  OperationalTo        212 non-null    object
#  12  Capacity             724 non-null    float64
#  13  LastUpdatedAt        733 non-null    object
#  14  Source               803 non-null    object
#  15  IAEAId               713 non-null    float64
# dtypes: float64(4), int64(1), object(11)
# memory usage: 100.5+ KB

# %%
# create a new dataframe for lattitude, longitude, name and country
df_1 = df[['Name', 'Country', 'Latitude', 'Longitude', 'Status', 'Capacity']]
df_1.head()
# Out:
#                    Name Country   Latitude  Longitude       Status  Capacity
# 0                Ågesta  Sweden  59.206000   18.08290     Shutdown       9.0
# 1  Akademik Lomonosov-1  Russia  69.709579  170.30625  Operational      30.0
# 2  Akademik Lomonosov-2  Russia  69.709579  170.30625  Operational      30.0
# 3              Akhvaz-1    Iran        NaN        NaN      Planned       NaN
# 4              Akhvaz-2    Iran        NaN        NaN      Planned       NaN

# %%
# identify missing values
df_1.isnull().sum()
# Out:
# Name          0
# Country       0
# Latitude     44
# Longitude    44
# Status        0
# Capacity     79
# dtype: int64

# %%
# get current mean of capacity
df_1['Capacity'].mean()
# Out:
# 778.4198895027624

# %%
# inpute missing values for capacity (will not effect mean as we are imputing the mean for the missing values)
df_1['Capacity'].fillna(df_1['Capacity'].mean(), inplace=True)
df_1.isnull().sum()
# Out:
# C:\Users\Ramon\AppData\Local\Temp\ipykernel_10888\4071410280.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Capacity'].fillna(df_1['Capacity'].mean(), inplace=True)
# Name          0
# Country       0
# Latitude     44
# Longitude    44
# Status        0
# Capacity      0
# dtype: int64

# %%
# create a list of only entries with missing values for latitude and longitude and save as a new dataframe
df_missing = df_1[df_1['Latitude'].isnull()]
df_missing.head()
# Out:
#                          Name Country  Latitude  Longitude   Status   Capacity
# 3                    Akhvaz-1    Iran       NaN        NaN  Planned  778.41989
# 4                    Akhvaz-2    Iran       NaN        NaN  Planned  778.41989
# 33                   Chutka-1   India       NaN        NaN  Planned  778.41989
# 34                   Chutka-2   India       NaN        NaN  Planned  778.41989
# 316  Hongshiding-1 (Rushan-1)   China       NaN        NaN  Planned  778.41989

# %%
# create new dataframe excluding missing values
df_map = df_1.dropna(axis=0, how='any')
df_map.head()
# Out:
#                    Name  Country   Latitude   Longitude              Status  \
# 0                Ågesta   Sweden  59.206000   18.082900            Shutdown
# 1  Akademik Lomonosov-1   Russia  69.709579  170.306250         Operational
# 2  Akademik Lomonosov-2   Russia  69.709579  170.306250         Operational
# 5              Akkuyu-1  Türkiye  36.144444   33.541111  Under Construction
# 6              Akkuyu-2  Türkiye  36.144444   33.541111  Under Construction
#
#    Capacity
# 0       9.0
# 1      30.0
# 2      30.0
# 5    1114.0
# 6    1114.0

# %%
# get unique values for status
df_map['Status'].unique()
# Out:
# array(['Shutdown', 'Operational', 'Under Construction', 'Planned',
#        'Cancelled Construction', 'Suspended Construction', 'Unknown',
#        'Decommissioning Completed', 'Suspended Operation',
#        'Never Commissioned'], dtype=object)

# %%
# plot map of nuclear power plants using folium
# Create a Folium map
m = folium.Map()

# Add markers to the map
for index, row in df_map.iterrows():
    name = row['Name']
    country = row['Country']
    latitude = row['Latitude']
    longitude = row['Longitude']
    status = row['Status']
    capacity = row['Capacity']

    marker_color = {
        'Operational': 'green',
        'Under Construction': 'yellow',
        'Planned': 'orange',
        'Cancelled Construction': 'red',
        'Suspended Construction': 'red',
        'Unknown': 'red',
        'Decommissioning Completed': 'red',
        'Suspended Operation': 'red',
        'Never Commissioned': 'red',
        'Shutdown': 'red'
    }[status]

    marker = folium.Marker([latitude, longitude], tooltip=f"{name} ({country}): {capacity} MWe")
    marker.add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_07dfda1d2f4fe001698eb6eb3df89cf2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_07dfda1d2f4fe001698eb6eb3df89cf2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_07dfda1d2f4fe001698eb6eb3df89cf2 = L.map(
#                 &quot;map_07dfda1d2f4fe001698eb6eb3df89cf2&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b1a5d66431cfeb418e134192e548f2e7 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_07dfda1d2f4fe001698eb6eb3df89cf2);
#
#
#             var marker_b50c518e94ada13db65d7d1105e0bfdb = L.marker(
#                 [59.206, 18.0829],
#                 {}
#             ).addTo(map_07dfda1d2f4fe001698eb6eb3df89cf2);
#
#
#             marker_b50c518e94ada13db65d7d1105e0bfdb.bindTooltip(
#                 `&lt;div&gt;
#                      Ågesta (Sweden): 9.0 MWe
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_a866c20e777abd81d1d6769aaa4cff61 = L.marker(
#                 [69.709579, 170.30625],
#                 {}
#             ).addTo(map_07dfda1d2f4fe001698eb6eb3df89cf2);
#
#
#             marker_a866c20e777abd81d1d6769aaa4cff61.bindTooltip(
#                 `&lt;div&gt;
#                      Akademik Lomonosov-1 (Russia): 30.0 MWe
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_820ab7c26e80393cb69556b4290a80cb = L.marker(
#                 [69.709579, 170.30625],
#                 {}
#             ).addTo(map_07dfda1d2f4fe001698eb6eb3df89cf2);
#
#
#             marker_820ab7c26e80393cb69556b4290a80cb.bindTooltip(
#                 `&lt;div&gt;
#                      Akademik Lomonosov-2 (Russia): 30.0 MWe
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_1ea3bea79f7129b704e9fe9058a16386 = L.marker(
#                 [36.144444, 33.541111],
#                 {}
#             ).addTo(map_07dfda1d2f4fe001698eb6eb3df89cf2);
#
#
#             marker_1ea3bea79f7129b704e9fe9058a16386.bindTooltip(
#                 `&lt;div&gt;
#                      Akkuyu-1 (Türkiye): 1114.0 MWe
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_4d3843eabf64566958af600146acc601 = L.marker(
#                 [36.144444, 33.541111],
#                 {}
#             ).addTo(map_07dfda1d2f4fe001698eb6eb3df89cf2);
#
#
#             marker_4d3843eabf64566958af600146acc601.bindTooltip(
#                 `&lt;div&gt;
#                      Akkuyu-2 (Türkiye): 1114.0 MWe
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_890c4fd06a08024f3168c79f8bbf7d4b = L.marker(
#                 [36.144444, 33.541111],
#                 {}
#             ).addTo(map_07dfda1d2f4fe001698eb6eb3df89cf2);
#
#
#             marker_890c4fd06a08024f3168c79f8bbf7d4b.bindTooltip(
#                 `&lt;div&gt;
#                      Akkuyu-3 (Türkiye): 1114.0 MWe
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_7b936bc2451dcdb0e21d3da24c6ff6bd = L.marker(
#                 [36.144444, 33.541111],
#                 {}
#             ).addTo(map_07dfda1d2f4fe001698eb6eb3df89cf2);
#
#
#             marker_7b936bc2451dcdb0e21d3da24c6ff6bd.bindTooltip(
#                 `&lt;div&gt;
#                      Akkuyu-4 (Türkiye): 1114.0 MWe
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_fb68f5b5164e92226a296377d0a4e23b = L.marker(
#                 [43.607, 51.283],
#                 {}
#             ).addTo(map_07dfda1d2f4fe001698eb6eb3df89cf2);
#
#
#             marker_fb68f5b5164e92226a296377d0a4e23b.bindTooltip(
#                 `&lt;div&gt;
#                      Aktau (Shevchenko) (Kazakhstan): 52.0 MWe
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_b22c0b63b9f582020cc89ca9ebfbd99a = L.marker(
#                 [39.807, -5.698],
#                 {}
#             ).addTo(map_07dfda1d2f4fe001698eb6eb3df89cf2);
#
#
#             marker_b22c0b63b9f582020cc89ca9ebfbd99a.bindTooltip(
#                 `&lt;div&gt;
#                      Almaraz-1 (Spain): 900.0 MWe
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c1a12c08418e223210ee79af
